# %% [markdown]
# <a href="https://colab.research.google.com/github/ViniciusVicentini/PA_Python/blob/main/C%C3%B3pia_de_Exercicios_juntos_La%C3%A7os%2C_condicionais%2C_listas%2C_tuplas_e_dicion%C3%A1rios_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lista de Exercícios unindo tudo que foi ensinado até o momento:
#
#
# *   Condicionais
# *   Laços de Reptição
# *   Listas
# *   Tuplas
# *   Dicionários
# *   Manipulação de Strings

# %% [markdown]
# # Tuplas - Acesso e Desempacotamento
#
# 1) Crie uma tupla contendo três tipos diferentes de dados: um número, uma string e uma lista. Use um laço de repetição para acessar e imprimir cada item da tupla. Além disso, dentro do laço, acesse e imprima o segundo item da lista que está dentro da tupla.

# %%
dados = (24, "Cíntia",[1,2,3])

for i in dados:
  print(i)
# Out:
# 24
# Cíntia
# [1, 2, 3]

# %%
dados[1]
# Out:
# 'Cíntia'

# %% [markdown]
# # Dicionários - Criação e Acesso
# ## Cadastro de Pessoas e Análise de Alturas
# 2) Solicite ao usuário para inserir o nome e a altura de várias pessoas. Preencha um dicionário com essas informações e depois encontre e imprima o nome e a altura da pessoa mais alta e da mais baixa.

# %%
pessoas = {}
altura_maior = 0


while True:
  nome = input("Digite aqui o nome: ").lower()
  if nome == "sair":
    break
  else:
    altura = float(input(f"Digite aqui a altura da: {nome}, em metros: " ))
    pessoas[nome] = altura
altura_maior = max(pessoas,key=pessoas.get)
altura_menor = min(pessoas,key=pessoas.get)

print(f"a pessoa com maior altura é: {altura_maior}")
print(f"a pessoa com menor altura é: {altura_menor}")
# Out:
# Digite aqui o nome: samir
# Digite aqui a altura da: samir, em metros: 1.90
# Digite aqui o nome: ramos
# Digite aqui a altura da: ramos, em metros: 1.00
# Digite aqui o nome: peruibe
# Digite aqui a altura da: peruibe, em metros: 3.40
# Digite aqui o nome: sair
# a pessoa com maior altura é: peruibe
# a pessoa com menor altura é: ramos

# %% [markdown]
# # Lista, laços e Condicionais
# 3) Descrição: Crie uma listacom cinco números inteiros. Use um laço de repetição e uma condicional para imprimir apenas os números que são múltiplos de 3.

# %%
numeros = []
multips = []

for i in range(0,5):
  nu = int(input("Digite aqui os cinco numeros: "))
  numeros.append(nu)

for nu in numeros:
   if nu % 3 == 0:
    multips.append(nu)
print("os numeros multiplos de 3 é: ", multips)
# Out:
# Digite aqui os cinco numeros: 3
# Digite aqui os cinco numeros: 6
# Digite aqui os cinco numeros: 9
# Digite aqui os cinco numeros: 12
# Digite aqui os cinco numeros: 5
# os numeros multiplos de 3 é:  [3, 6, 9, 12]

# %%
numeros
# Out:
# ['3', '6', '9', '12', '18']

# %% [markdown]
# # Manipulação de Strings e Condicionais
# 4) Descrição: Crie uma string com uma frase. Use uma condicional para verificar se a frase contém a palavra "Python". Se sim, substitua a palavra "Python" por "programação" e imprima a nova frase.

# %%
frase = input("Digite aqui a frase: ").lower()

if "python" in frase:
  nova_frase = frase.replace("python", "programaçao")
  print("a nova frase é: ", nova_frase)
else:
  print("a frase nao tem a palavra python")
# Out:
# Digite aqui a frase: eu gosto de python
# a nova frase é:  eu gosto de programaçao

# %% [markdown]
# # Simulação de Alfândega com Cadastro Dinâmico de Itens usando dicionário
# 5) Simule uma situação de alfândega onde o funcionário cadastra itens novos encontrados na mala de uma pessoa que veio de uma viagem internacional. Após o cadastro de todos os itens, o programa imprime uma nota com todos os itens e seus preços, calcula o valor total e, se o valor total ultrapassar 500 dólares, calcula o valor de 60% a ser pago.

# %%
mala = {}

while True:
  itens = input("Digite aqui os itens: (ou 1 para sair) ").lower()
  if itens == "1":
    print("Obrigado pelo serviço, volte sempre!")
    break
  preco = float(input("Digite aqui o preço do item: "))
  mala[itens] = preco

print("-------Nota Fiscal---------")
for itens, preco in mala.items():
  print(itens, ": $", preco)
valor_total = sum(mala.values())
print("O valor total é: ", valor_total)
if valor_total > 500:
  taxa = valor_total * 0.6

print("O valor total da sua mala é: ", valor_total)
print("O valor da taxa a ser pago é: ", taxa)
# Out:
# Digite aqui os itens: (ou 1 para sair) guarda-chuva
# Digite aqui o preço do item: 20
# Digite aqui os itens: (ou 1 para sair) tablet
# Digite aqui o preço do item: 2000
# Digite aqui os itens: (ou 1 para sair) celular
# Digite aqui o preço do item: 1500
# Digite aqui os itens: (ou 1 para sair) 1
# Obrigado pelo serviço, volte sempre!
# -------Nota Fiscal---------
# guarda-chuva : $ 20.0
# tablet : $ 2000.0
# celular : $ 1500.0
# O valor total é:  3520.0
# O valor total da sua mala é:  3520.0
# O valor da taxa a ser pago é:  2112.0

# %%
mala
# Out:
# {'guarda-chuva': 20.0, 'tablet': 2000.0, 'celular': 1500.0}

# %%
preco
# Out:
# 1500.0

# %% [markdown]
# # Identificação de Palavras Negativas em um Texto
# 6) Você vai criar um programa em Python para analisar um texto e identificar palavras que expressam pensamentos negativos. Para isso, você usará uma lista de palavras negativas fornecida e verificará quais dessas palavras estão presentes no texto fornecido pelo usuário. Exemplo de palavras negtivas, acrescente mais na lista: # Lista de palavras negativas palavras_negativas = ['triste', 'deprimido', 'ansioso', 'desapontado', 'frustrado']

# %%
palavras_negativas = ['triste', 'deprimido', 'ansioso', 'desapontado', 'frustrado']

texto = input("Digite um texto: ").lower()

encontradas = []

for palavra in palavras_negativas:
    if palavra in texto:
        encontradas.append(palavra)

if encontradas:
    print("As Palavras negativas encontradas foram:", encontradas)
else:
    print("Nenhuma palavra negativa foi encontrada.")
# Out:
# Digite um texto: eu estou triste, ansioso e frustrado
# Palavras negativas encontradas: ['triste', 'ansioso', 'frustrado']
