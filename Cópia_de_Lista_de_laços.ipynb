# %% [markdown]
# <a href="https://colab.research.google.com/github/ViniciusVicentini/PA_Python/blob/main/C%C3%B3pia_de_Lista_de_la%C3%A7os.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Nova Lista de Exercícios

# %% [markdown]
# **Exercícios com for, while, listas, strings e dicionários**

# %% [markdown]
# 1) Soma dos números de uma lista
#
# Dada a lista numeros = [3, 7, 2, 8, 10], use um for para calcular a soma de todos os elementos.

# %%
numeros = [3, 7, 2, 8, 10]

soma = 0
for n in numeros:
    soma = soma + n

print(soma)
# Out:
# 30

# %% [markdown]
# 2) Contagem de vogais em uma string
#
# Peça uma palavra ao usuário e use um for para contar quantas vogais (a, e, i, o, u) existem.

# %%
palavra = input("Digite aqui uma palavra: ")
vogais = "aeiou"
encontradas = 0

for letra in palavra:
  if letra.lower() in vogais:
    encontradas = encontradas + 1

print("nessa palavra há: ", encontradas, "vogais")
# Out:
# Digite aqui uma palavra: samir
# nessa palavra há:  2 vogais

# %% [markdown]
# 3) Inverter lista usando while
#
# Dada a lista nomes = ["Ana", "João", "Carlos", "Maria"], use um while para inverter a ordem dos elementos (sem usar reverse() ou slicing).

# %%
nomes = ["Ana", "João", "Carlos", "Maria"]

n = 0
l = len(nomes) - 1

while n < l:
    nomes[n], nomes[l] = nomes[l], nomes[n]

    n = n + 1
    l = l - 1

print(nomes)
# Out:
# ['Maria', 'Carlos', 'João', 'Ana']

# %% [markdown]
# 4) Maior número em uma lista
#
# Escreva um programa que percorra uma lista de inteiros e encontre o maior valor.

# %%
inteiros = [10, 20, 30, 80, 120]

maior_valor = inteiros[0]

for numero in inteiros:
    if numero > maior_valor:
        maior_valor = numero

print(maior_valor)
# Out:
# 120

# %% [markdown]
# 5) Remover elementos repetidos de uma lista
#
# Usando um for, percorra a lista valores = [1, 2, 2, 3, 4, 4, 5] e crie uma nova lista apenas com elementos únicos.

# %%
lista = [1, 2, 2, 3, 4, 4, 5]


nova_lista = []


for numero in lista:
    if numero not in nova_lista:
        nova_lista.append(numero)


print("A lista sem numeros repetidos é:", nova_lista)
# Out:
# A lista sem repetidos é: [1, 2, 3, 4, 5]

# %% [markdown]
# 6) Verificar se palavra é palíndromo
#
# Peça uma palavra ao usuário e use while ou for para verificar se ela é igual de frente para trás (ex.: "arara").

# %%
while True:
  palavra = input("Digite uma palavra: ")
  if palavra == "0":
    print("programa encerrado.")
    break
  elif palavra == palavra[::-1]:
    print("Essa palavra é igual de frente para trás")
  else:
    print("Essa palavra nao é igual de frente para tras")
# Out:
# Digite uma palavra: arara
# Essa palavra é igual de frente para trás
# Digite uma palavra: samir
# Essa palavra nao é igual de frente para tras
# Digite uma palavra: 0
# programa encerrado

# %% [markdown]
# 7 Contagem regressiva com while
#
# Peça ao usuário um número e faça uma contagem regressiva até 0.

# %%
numeros = int(input("digite um numero para uma contagem regressiva: "))
for i in range(numeros):
  print(numeros - 1)
  numeros = numeros -1
# Out:
# digite um numero para uma contagem regressiva: 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# 8) Percorrendo um dicionário de notas
#
# Dado o dicionário notas = {"Ana": 8, "Carlos": 7, "Maria": 10}, use um for para exibir cada aluno com sua nota.

# %%
notas = {"Ana": 8, "Carlos": 7, "Maria": 10}
for nomes, nota in notas.items():
  print("nome:", nomes, "nota:", nota)
# Out:
# nome: Ana nota: 8
# nome: Carlos nota: 7
# nome: Maria nota: 10

# %% [markdown]
# 9)Filtrar números pares de uma lista
#
# Dada a lista numeros = [10, 21, 32, 43, 54], use um for para criar uma nova lista contendo apenas os pares.

# %%
numeros = [10, 21, 32, 43, 54]
pares = []

for i in numeros:
  if i%2 == 0:
    pares.append(i)

print(pares)
# Out:
# [10, 32, 54]

# %% [markdown]
# 10) Contador de palavras em uma frase
#
# Peça ao usuário uma frase, divida em palavras (split()) e use um dicionário para contar quantas vezes cada palavra aparece.

# %%
frase = input("Digite uma frase: ")

palavra = ""
palavras = []

for letra in frase:
    if letra != " ":
        palavra = palavra + letra
    else:
        palavras.append(palavra)
        palavra = ""


palavras.append(palavra)


contagem = {}

for p in palavras:
    if p in contagem:
        contagem[p] = contagem[p] + 1
    else:
        contagem[p] = 1


print("Contagem de palavras:")
for cont in contagem:
    print(cont, ":", contagem[cont])
# Out:
# Digite uma frase: eu eu jogo fute fute bola
# Contagem de palavras:
# eu : 2
# jogo : 1
# fute : 2
# bola : 1
