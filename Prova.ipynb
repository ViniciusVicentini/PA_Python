# %% [markdown]
# <a href="https://colab.research.google.com/github/ViniciusVicentini/PA_Python/blob/main/Prova.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1)	Detector de Fases da Lua (Situação hipotética)
# #Faça um programa que pergunte o dia do mês (1 a 31) Não aceite valores fora desse intervalo.
# #Baseado no dia, informe a provável fase da lua:
# ##•  Dia 1 a 7: Lua Nova
# ##•  Dia 8 a 14: Quarto Crescente
# ##•  Dia 15 a 21: Lua Cheia
# ##•  Dia 22 a 29: Quarto Minguante
# ##•  Dia 30 ou mais: Início de novo ciclo lunar

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dia = int(input("Digite aqui o dia: "))
# Out:
# Digite aqui o dia: 9

# %%
if dia >= 1 and dia <= 31:
  print("Dia valido")
  if dia >= 1 and dia <= 7:
    print("Lua Nova")
  elif dia >= 8 and dia <= 14:
    print("Quarto Crescente")
  elif dia >= 15 and dia <= 21:
    print("Lua Cheia")
  elif dia >= 22 and dia <= 29:
    print("Quarto Minguante")
  else:
    print("Inicio Do Novo Ciclo Lunar")
else:
  print("Dia invalido")
# Out:
# Dia valido
# Quarto Crescente

# %% [markdown]
# #2)	Crie um programa que simule a entrada de um jogador em uma batalha de RPG. O usuário deverá informar:
# ##•	Sua classe: "mago", "guerreiro" ou "arqueiro" (deve dar erro se as entradas forem diferentes dessas.
# ##•	Sua energia (valor de 0 a 100)
# #Regras de entrada:
# ##•	Magos: precisam ter energia > 60
# ##•	Guerreiros: energia > 40
# ##•	Arqueiros: energia > 50
# #Se puder entrar na batalha, o programa deve calcular um dano base diferente para cada classe:
# ##•	Mago: dano = energia × 1.5
# ##•	Guerreiro: dano = energia × 2
# ##•	Arqueiro: dano = energia × 1.2
# #O programa deve exibir:
# ##•	Se o jogador pode ou não entrar
# ##•	E, se puder, mostrar seu dano base calculado
# #Exemplo da saída:
# #Classe: guerreiro
# #Energia: 55
# #Você pode entrar na batalha!
# #Dano base: 110.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
energia = int(input("Digite aqui a sua energia: "))
# Out:
# Digite aqui a sua energia: 2

# %%
if energia >= 1 and energia <= 100:
  classe = int(input("Digite a sua classe:\n1 para Mago\n2 para Guerreiro\n3 para Arqueiro "))
  if classe == 1:
    energia = energia*1.5
    if energia >= 60:
      print("Entrou na batalha")
    else:
      print("Sua energia nao é suficiente")
  elif classe == 2:
    energia = energia*2
    if energia >= 40:
      print("Entrou na batalha")
    else:
      print("Sua energia nao é suficiente")
  elif classe == 3:
    energia = energia*1.2
    if energia >= 50:
      print("Entrou na batalha")
    else:
      print("Sua energia nao é suficiente")
  else:
    print("Numero Invalido")
else:
  print("Invalido")
# Out:
# Digite a sua classe:
# 1 para Mago
# 2 para Guerreiro
# 3 para Arqueiro 1
# Nao foi

# %% [markdown]
# # Descrição do Algoritmo:
# 1. Início
# ##•	Solicita-se a renda familiar mensal (em reais).
# 2. Validação da Renda
# ##•	Se a renda familiar for menor que 0, exibir:
# ##➤ "Renda inválida"
# ##•	Se a renda familiar for maior que R$ 5.000, exibir:
# ##➤ "Não participa da bolsa. Só participam candidatos com renda menor ou igual a R$ 5.000."
# 3. Tipo de Escola
# ##•	Solicitar o tipo de escola do candidato: "pública" ou "particular".
# ##•	Se for outro valor, exibir:
# ##➤ "Tipo de escola inválido"
# ##➤ Encerrar o programa.
# 4. Notas Anuais
# ##•	Solicitar as três últimas notas anuais nas disciplinas:
# #o	Matemática
# #o	Português
# #o	Conhecimentos Gerais
# #•	Para cada nota, validar se está entre 1 e 10:
# ##o	Se alguma estiver fora desse intervalo, exibir erro específico:
# ##➤ "Nota inválida. Reinicie o preenchimento."
# ##➤ Encerrar o programa.
# ##•	Calcular a média simples das três notas.
# #Observação: Essa média poderá ser superior a 10 após os bônus.
#
# #Processamento por Tipo de Escola e Média
# #Se a escola for pública:
# #Média ≥ 8:
# ##•	Aumentar a média em 20%;
# ##•	Se a renda < R$ 3.000, aplicar mais 15% sobre o novo valor da média.
# #Média ≥ 6 e < 8:
# ##•	Aumentar a média em 10%;
# ##•	Se a renda < R$ 3.000, aplicar mais 5% sobre o novo valor da média.
# #Média < 6:
# ##•	Exibir:
# #➤ "Não concorre à bolsa por nota baixa."
# ##Se a escola for particular:
# #Média ≥ 8:
# ##•	Aumentar a média em 5%;
# ##•	Se a renda < R$ 3.000, aplicar mais 15% sobre o novo valor da média.
# #Média ≥ 6 e < 8:
# ##•	Aumentar a média em 2,5%;
# ##•	Se a renda < R$ 3.000, aplicar mais 2% sobre o novo valor da média.
# #Média < 6:
# ##•	Exibir:
# ##➤ "Não concorre à bolsa por nota baixa."

# %%
# Out:
# Digite a renda familiar mensal: 3
# Invalido

# %%
#Final Boss of condicional
renda = float(input("Digite a renda familiar mensal: R$"))
if renda <= 0:
  print("Renda inválida")
elif renda > 5000:
  print("Não participa da bolsa. Só participam candidatos com renda menor que de R$5.000,00")
else:
  escola = int(input("Qual é o tipo da sua escola? \nDigite 1 para pública \n 2 para escola particular"))
  if escola == 1:
    print("Digite as últimas notas dessas matérias")
    matematica = float(input("Matemática: "))
    if matematica >= 0 and mat <= 10:
      portugues = float(input("Português: "))
      if portugues >= 0 and port <= 10:
        conhecimentos_gerais = float(input("Conhecimentos gerais: "))
        if conhecimentos_gerais >= 0 and conhecimentos_gerais <=10:
          media = (matematica + portugues + conhecimentos_gerais)/3
          if media >= 8:
            media = media + (media * 0.2)
            print(f"A média subiu para {media:.2f}")
            if renda < 3000:
              media_final = media + (media * 0.15)
              print(f"Como a Renda Familiar é de menos de R$3000,00, a média subiu para {media_final:.2f}")
          elif media >= 6 and media < 8:
            media = media + (media * 0.1)
            print(f"A média subiu para {media:.2f}")
            if renda < 3000:
              media_final = media + (media * 0.05)
              print(f"Como a Renda Familiar é de menos de R$3000,00, a média subiu para {media_final:.2f}")
          elif media < 6:
            print("Não concorre à bolsa por nota baixa")
        else:
          print("Nota inválida")
      else:
        print("Nota inválida")
    else:
      print("Nota inválida")
  elif escola == 2:
    print("Digite as últimas notas dessas matérias")
    matematica = float(input("Matemática: "))
    if matematica >= 0 and matematica <= 10:
      portugues = float(input("Português: "))
      if portugues >= 0 and portugues <= 10:
        conhecimentos_gerais = float(input("Conhecimentos gerais: "))
        if conhecimentos_gerais >= 0 and conhecimentos_gerais <=10:
          media = (matematica + portugues + conhecimentos_gerais)/3
          if media >= 8:
            media = media + (media * 0.05)
            print(f"A média subiu para {media:.2f}")
            if renda < 3000:
              media_final = media + (media * 0.15)
              print(f"Como a Renda Familiar é de menos de R$3000,00, a média subiu para {media_final:.2f}")
          elif media >= 6 and media < 8:
            media = media + (media * 0.025)
            print(f"A média subiu para {media:.2f}")
            if renda < 3000:
              media_final = media + (media * 0.02)
              print(f"Como a Renda Familiar é de menos de R$3000,00, a média subiu para {media_final:.2f}")
          elif media < 6:
            print("Não concorre à bolsa por nota baixa")
        else:
          print("Nota inválida")
      else:
        print("Nota inválida")
    else:
      print("Nota inválida")
  else:
    print("Esse tipo de escola é inválida.")
# Out:
# Digite a renda familiar mensal: R$5000
# Qual é o tipo da sua escola?
# Digite 1 para pública
#  2 para escola particular2
# Digite as últimas notas dessas matérias
# Matemática: 9
# Português: 9
# Conhecimentos gerais: 9
# A média subiu para 9.45
